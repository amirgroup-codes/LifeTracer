# %% [markdown]
# # Logistic Regression Results
#
# This notebook demonstrates **Step 7** from the complete pipeline (`reproduce_paper_results.ipynb`), focusing specifically on logistic regression analysis and generating the plots used in the research paper.
#
# ## Prerequisites
#
# - **Storage Requirements**: This notebook requires minimal storage (~2GB) compared to the full pipeline
# - **Data Dependencies**: Assumes peaks and features are already extracted from previous pipeline steps
# - **Alternative**: Run the complete `reproduce_paper_results.ipynb` if you want to follow all steps and have at least 750 GB storage available
#
# ## What This Notebook Does
#
# 1. Downloads pre-processed peaks and features data
# 2. Runs logistic regression classification with L2 regularization
# 3. Generates evaluation metrics and plots
# 4. Outputs results matching those reported in the paper

# %% [markdown]
# ## Setup Instructions

# %% [markdown]
# ### LifeTracer Package Installation
#
# **For Linux/macOS:**
#
#
# ```bash
# # Clone the repo:
# git clone git@github.com:amirgroup-codes/LifeTracer.git
#
# # Step 1: Create conda environment
# conda create -n LifeTracer python=3.10.8
#
# # Step 2: Activate environment
# conda activate LifeTracer
#
# # Step 3: Navigate to project directory and install
# cd LifeTracer
# pip install -e .
#
# # Step 4: Verify installation
# python -c "import lifetracer; print('LifeTracer installed successfully!')"
# ```
#
# **For Windows:**
#
# Use Anaconda Prompt or PowerShell and follow the same commands above.
#
# ### Common Installation Issues
#
# | Issue | Solution |
# |-------|----------|
# | Permission Errors | Use `pip install --user -e .` |
# | Environment Issues | Run `conda clean --all` and recreate environment |
# | Path Problems | Ensure you're in the correct project directory |
# | Import Errors | Verify Python version is 3.10.8 |

# %% [markdown]
# ## Data Download
#
# Download the required pre-processed data (peaks and features) from the previous pipeline steps:

# %%
import os
import urllib.request

# Download all samples
download_list = [
    'https://huggingface.co/datasets/DS-20202/LifeTracer-Processed-Data/resolve/main/features.zip',
    'https://huggingface.co/datasets/DS-20202/LifeTracer-Processed-Data/resolve/main/peaks.zip',
]

# create a folder for the raw data
os.makedirs('output', exist_ok=True)

# Download the data and store in output folder
for url in download_list:
    filename = url.split('/')[-1]
    print(f"Downloading {filename}...")
    urllib.request.urlretrieve(url, f"output/{filename}")
    print(f"Downloaded {filename}")

# Unzip the data
import zipfile

print("Extracting features.zip...")
with zipfile.ZipFile('output/features.zip', 'r') as zip_ref:
    zip_ref.extractall('output/')

print("Extracting peaks.zip...")
with zipfile.ZipFile('output/peaks.zip', 'r') as zip_ref:
    zip_ref.extractall('output/')

print("Extraction complete!")

# %% [markdown]
# ## Running Logistic Regression
#
# Execute the following cell to perform logistic regression classification and generate the plots used in the paper. The results are located in `output/lr_l2_results/`.

# %%
import lifetracer

config = {
    "mz_list_path": "data/all_mz_values.csv",
    "labels_path": "data/labels.csv",
    "m_z_column_name": "M/Z",
    "area_column_name": "Area",
    "first_time_column_name": "1st Time (s)",
    "second_time_column_name": "2nd Time (s)",
    "csv_file_name_column": "csv_file_name",
    "label_column_name": "label",

    "features_path": "output/features/",
    "peaks_dir_path": "output/peaks/",
    "results_dir": "output/lr_l2_results/",

    # Logistic Regression with l2 regularization
    "C": 0.1, # best C from step 6
    "seed": 42, 
    "lambda1": 5, # Selected from calibration step
    "lambda2": 100, # Selected from calibration step
    "rt1_threshold": 50, # Selected from calibration step
    "rt2_threshold": 0.8, # Selected from calibration step
}

lifetracer.binary_classifier.binary_classifier(config)
# Out:
# 2025-09-03 16:45:17.857 | INFO     | lifetracer.src.binary_classifier:binary_classifier:324 - Intercept: [0.03806688]
# 2025-09-03 16:45:27.251 | INFO     | lifetracer.src.binary_classifier:binary_classifier:348 - Signatures saved.
# Folder created here: output/lr_l2_results/top_features/
# Folder created here: output/lr_l2_results/feature_groups
# 2025-09-03 16:45:28.317 | INFO     | lifetracer.src.binary_classifier:binary_classifier:375 - Removed 30 indices from top_feature_group_indices manually
# 2025-09-03 16:45:29.596 | INFO     | lifetracer.src.binary_classifier:binary_classifier:387 - Top 10 signatures plotted in top_coefficients folder.
# 2025-09-03 16:45:29.886 | INFO     | lifetracer.src.binary_classifier:binary_classifier:391 - PCA plot saved.
# 2025-09-03 16:47:05.374 | INFO     | lifetracer.src.binary_classifier:binary_classifier:409 - 3D plot of signatures (png) saved.
# 2025-09-03 16:47:06.127 | INFO     | lifetracer.src.binary_classifier:binary_classifier:413 - 3D interactive plot of peaks saved.
# 2025-09-03 16:47:06.985 | INFO     | lifetracer.src.binary_classifier:binary_classifier:417 - 3D interactive plot of signatures saved.
# 2025-09-03 16:47:07.380 | INFO     | lifetracer.src.binary_classifier:binary_classifier:420 - 3D plot of feature groups saved.
# 3.472 0.04
# 2025-09-03 16:47:08.349 | INFO     | lifetracer.src.binary_classifier:binary_classifier:426 - Distribution of peaks across m/z values saved.
# 2025-09-03 16:47:08.352 | INFO     | lifetracer.src.binary_classifier:mann_whitney_u_test_mz:110 - Mann Whitney U test for m/z p-value: 0.9999999966445333
# 2025-09-03 16:47:08.353 | INFO     | lifetracer.src.binary_classifier:mann_whitney_u_test_mz:115 - Fail to reject null hypothesis-> Abiotic peak distribution for m/z is not significantly lower than biotic
# 2025-09-03 16:47:08.357 | INFO     | lifetracer.src.binary_classifier:mann_whitney_u_test_rt1:123 - Mann Whitney U test for RT1 p-value: 6.465282194451019e-209
# 2025-09-03 16:47:08.358 | INFO     | lifetracer.src.binary_classifier:mann_whitney_u_test_rt1:126 - Reject null hypothesis-> Abiotic peak distribution for RT1 is significantly lower than biotic
# 2025-09-03 16:47:08.362 | INFO     | lifetracer.src.binary_classifier:mann_whitney_u_test_rt2:136 - Mann Whitney U test for RT2 p-value: 0.9999999998117325
# 2025-09-03 16:47:08.363 | INFO     | lifetracer.src.binary_classifier:mann_whitney_u_test_rt2:141 - Fail to reject null hypothesis-> Abiotic peak distribution for RT2 is not significantly higher than biotic
# 2025-09-03 16:47:08.376 | INFO     | lifetracer.src.binary_classifier:kolmogorov_smirnov_test:149 - Kolmogorov-Smirnov test for m/z - statistic: 0.1467191386019838, p-value: 1.0606304638923022e-20
# 2025-09-03 16:47:08.377 | INFO     | lifetracer.src.binary_classifier:kolmogorov_smirnov_test:152 - Reject null hypothesis -> The distributions of m/z for abiotic and biotic peaks are significantly different
# 2025-09-03 16:47:08.431 | INFO     | lifetracer.src.binary_classifier:kolmogorov_smirnov_test:149 - Kolmogorov-Smirnov test for RT1 - statistic: 0.45691332377524846, p-value: 1.1326092556406119e-203
# 2025-09-03 16:47:08.432 | INFO     | lifetracer.src.binary_classifier:kolmogorov_smirnov_test:152 - Reject null hypothesis -> The distributions of RT1 for abiotic and biotic peaks are significantly different
# 2025-09-03 16:47:08.446 | INFO     | lifetracer.src.binary_classifier:kolmogorov_smirnov_test:149 - Kolmogorov-Smirnov test for RT2 - statistic: 0.14881977158127785, p-value: 2.7510370654389267e-21
# 2025-09-03 16:47:08.446 | INFO     | lifetracer.src.binary_classifier:kolmogorov_smirnov_test:152 - Reject null hypothesis -> The distributions of RT2 for abiotic and biotic peaks are significantly different
# 2025-09-03 16:47:14.333 | INFO     | lifetracer.src.binary_classifier:plot_accuracy_drop_zeroing_coefficients:205 - Classification accuracy remained above 90% after removing top 1773 features
# 2025-09-03 16:47:14.335 | INFO     | lifetracer.src.binary_classifier:plot_accuracy_drop_zeroing_coefficients:206 - Classification accuracy remained above 80% after removing top 2099 features
# 2025-09-03 16:47:14.504 | INFO     | lifetracer.src.binary_classifier:binary_classifier:439 - Accuracy drop plot saved.
# 2025-09-03 16:47:14.506 | INFO     | lifetracer.src.binary_classifier:binary_classifier:443 - Accuracy before zeroing out the coefficients of the noisy feature groups: 1.0
# 2025-09-03 16:47:14.621 | INFO     | lifetracer.src.binary_classifier:binary_classifier:463 - Accuracy after zeroing out the coefficients of the noisy feature groups: 1.0

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Data Download (Optional)
#
# **Note**: If you haven't run the data download section above, execute the cell below to download the required datasets:

# %%
import os
import urllib.request

# Download all samples
download_list = [
    'https://huggingface.co/datasets/DS-20202/LifeTracer-Processed-Data/resolve/main/features.zip',
    'https://huggingface.co/datasets/DS-20202/LifeTracer-Processed-Data/resolve/main/peaks.zip',
]

# create a folder for the raw data
os.makedirs('output', exist_ok=True)

# Download the data and store in output folder
for url in download_list:
    filename = url.split('/')[-1]
    print(f"Downloading {filename}...")
    urllib.request.urlretrieve(url, f"output/{filename}")
    print(f"Downloaded {filename}")

# Unzip the data
import zipfile

print("Extracting features.zip...")
with zipfile.ZipFile('output/features.zip', 'r') as zip_ref:
    zip_ref.extractall('output/')

print("Extracting peaks.zip...")
with zipfile.ZipFile('output/peaks.zip', 'r') as zip_ref:
    zip_ref.extractall('output/')

print("Extraction complete!")
# Out:
# Downloading features.zip...
# Downloaded features.zip
# Downloading peaks.zip...
# Downloaded peaks.zip
# Extracting features.zip...
# Extracting peaks.zip...
# Extraction complete!

# %% [markdown]
# ### Model Evaluation Configuration
#
# Configure and run the evaluation with different machine learning models. The default configuration uses **Logistic Regression with L2 regularization**.

# %%
import lifetracer

config = {
    "parallel_processing": True,
    "mz_list_path": "data/all_mz_values.csv",
    "labels_path": "data/labels.csv",
    "m_z_column_name": "M/Z",
    "area_column_name": "Area",
    "first_time_column_name": "1st Time (s)",
    "second_time_column_name": "2nd Time (s)",
    "csv_file_name_column": "csv_file_name",
    "label_column_name": "label",

    # Note: If you did not run all the steps, you can download the features and peaks from the huggingface.
    # You can download the features and peaks from the huggingface. Follow the instructions in the notebook to download the data.
    # Download features: https://huggingface.co/datasets/DS-20202/LifeTracer-Processed-Data/resolve/main/features.zip
    # Download peaks: https://huggingface.co/datasets/DS-20202/LifeTracer-Processed-Data/resolve/main/peaks.zip
    "features_path": "output/features", # Path to features directory
    "peaks_dir_path": "output/peaks", # Path to peaks directory
    "eval_path":"output/eval/lr_l2", # Change the path to your desired output directory
    
    "model": "lr_l2",
    "lr_l2": {
        "C": [1e-4,1e-3,1e-2,1e-1,1e0,1e+1,1e+2,1e+3,1e+4],
        "lambda1": [5],
        "lambda2": [100],
        "rt1_threshold": [50],
        "rt2_threshold": [0.8],
    }

    # Uncomment the model you want to evaluate

    # "model": "lr_l1",
    # "lr_l1": {
    #     "C": [1e-4,1e-3,1e-2,1e-1,1e0,1e+1,1e+2,1e+3,1e+4],
    #     "lambda1": [5],
    #     "lambda2": [100],
    #     "rt1_threshold": [50],
    #     "rt2_threshold": [0.8],
    # }

    
    # "model": "svm",
    # "svm": {
    #     "C": [1e-3,1e-2,1e-1,1e0,1e+1,1e+2,1e+3],
    #     "kernel": ["linear","poly","rbf","sigmoid"],
    #     "lambda1": [5],
    #     "lambda2": [100],
    #     "rt1_threshold": [50],
    #     "rt2_threshold": [0.8],
    # },

    # "model": "rf",
    # "rf": {
    #     "n_estimators": [20, 50, 100, 200, 500],
    #     "lambda1": [5],
    #     "lambda2": [100],
    #     "rt1_threshold": [50],
    #     "rt2_threshold": [0.8],
    # }

    # "model": 'NaiveBayes',
    # "NaiveBayes": {
    #     "alpha": [0.01, 0.1, 0.5, 1, 5, 10],
    #     "lambda1": [5],
    #     "lambda2": [100],
    #     "rt1_threshold": [50],
    #     "rt2_threshold": [0.8],
    # }
}

lifetracer.evaluation.eval(config)
# Out:
# 2025-09-03 16:12:09.623 | INFO     | lifetracer.src.evaluation:eval:379 - Model: lr_l2
# 2025-09-03 16:12:09.626 | INFO     | lifetracer.src.evaluation:eval:380 - Starting evaluation
# Folder created here: output/eval/lr_l2
# Parallel processing
# Seed 741 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.93it/s]
# Seed 627 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.96it/s]
# Seed 661 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.88it/s]
# Seed 522 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.87it/s]
# Seed 137 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.05it/s]
# Seed 860 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.05it/s]
# Seed 412 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.74it/s]
# Seed 514 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.67it/s]
# Seed 738 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.63it/s]
# Seed 679 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.65it/s]
# Seed 741 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.68it/s]
# Seed 522 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.83it/s]
# Seed 514 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.93it/s]
# Seed 661 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.68it/s]
# Seed 627 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.66it/s]
# Seed 137 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.75it/s]
# Seed 679 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.08it/s]
# Seed 738 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.87it/s]
# Seed 412 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.77it/s]
# Seed 860 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.65it/s]
# Seed 741 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.02it/s]
# Seed 522 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.75it/s]
# Seed 627 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.88it/s]
# Seed 412 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.90it/s]
# Seed 679 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.83it/s]
# Seed 514 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.74it/s]
# Seed 661 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.77it/s]
# Seed 137 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.79it/s]
# Seed 738 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.79it/s]
# Seed 860 - Processing parameters: 100%|██████████| 9/9 [00:03<00:00,  2.81it/s]
# Seed 741 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.31it/s]
# Seed 412 - Processing parameters: 100%|██████████| 9/9 [00:01<00:00,  4.80it/s]
# Seed 627 - Processing parameters: 100%|██████████| 9/9 [00:01<00:00,  4.63it/s]
# Seed 738 - Processing parameters: 100%|██████████| 9/9 [00:01<00:00,  5.02it/s]
# Seed 522 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.39it/s]
# Seed 514 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.43it/s]
# Seed 679 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.32it/s]
# Seed 860 - Processing parameters: 100%|██████████| 9/9 [00:01<00:00,  4.76it/s]
# Seed 661 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.22it/s]
# Seed 137 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.19it/s]
# Seed 741 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.21it/s]
# Seed 627 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.30it/s]
# Seed 412 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.21it/s]
# Seed 738 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.14it/s]
# Seed 514 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.38it/s]
# Seed 522 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.19it/s]
# Seed 860 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.34it/s]
# Seed 137 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.22it/s]
# Seed 661 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.11it/s]
# Seed 679 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.03it/s]
# Seed 412 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.99it/s]
# Seed 741 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.66it/s]
# Seed 738 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.97it/s]
# Seed 627 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.68it/s]
# Seed 514 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.89it/s]
# Seed 522 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.77it/s]
# Seed 679 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.23it/s]
# Seed 661 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.03it/s]
# Seed 860 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.66it/s]
# Seed 137 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.84it/s]
# Seed 412 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.49it/s]
# Seed 522 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.71it/s]
# Seed 741 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.39it/s]
# Seed 679 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.69it/s]
# Seed 738 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.39it/s]
# Seed 661 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.78it/s]
# Seed 627 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.42it/s]
# Seed 860 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.80it/s]
# Seed 514 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.40it/s]
# Seed 137 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.41it/s]
# Seed 412 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.18it/s]
# Seed 522 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.30it/s]
# Seed 661 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.35it/s]
# Seed 738 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.20it/s]
# Seed 860 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.20it/s]
# Seed 741 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.00it/s]
# Seed 679 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.05it/s]
# Seed 627 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.00it/s]
# Seed 514 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.01it/s]
# Seed 137 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.23it/s]
# Seed 514 - Processing parameters:  89%|████████▉ | 8/9 [00:01<00:00,  3.94it/s]
# Seed 522 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.02it/s]
# Seed 661 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.98it/s]
# Seed 738 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.95it/s]
# Seed 860 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  3.98it/s]
# Seed 741 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.01it/s]
# Seed 679 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.01it/s]
# Seed 514 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.18it/s]
# Seed 627 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.08it/s]
# Seed 137 - Processing parameters: 100%|██████████| 9/9 [00:02<00:00,  4.38it/s]
# 2025-09-03 16:12:49.929 | INFO     | lifetracer.src.evaluation:eval:426 - Evaluation finished
# 2025-09-03 16:12:50.203 | INFO     | lifetracer.src.evaluation:calc_accuracy:354 - avg validation acc: 91.1111111111111±0.6054026310473108
# 2025-09-03 16:12:50.212 | INFO     | lifetracer.src.evaluation:calc_accuracy:355 - avg test acc: 87.22222222222223±5.583264233956051
# [np.float64(88.88888888888889), np.float64(72.22222222222221), np.float64(88.88888888888889), np.float64(88.88888888888889), np.float64(88.88888888888889), np.float64(88.88888888888889), np.float64(94.44444444444444), np.float64(88.88888888888889), np.float64(83.33333333333334), np.float64(88.88888888888889)]
# [np.float64(20.78698548207745), np.float64(41.5739709641549), np.float64(20.78698548207745), np.float64(20.78698548207745), np.float64(20.78698548207745), np.float64(20.78698548207745), np.float64(15.713484026367725), np.float64(20.78698548207745), np.float64(23.570226039551585), np.float64(20.78698548207745)]
